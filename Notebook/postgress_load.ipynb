# %%
import sys
sys.path.append(r"C:\Users\Baslael\Documents\Kifiya\week2\script")

from main import load_data_from_postgres,nan_values,to_percent

# %%
query="SELECT * FROM xdr_data"

df=load_data_from_postgres(query)
df
# Out:
#                   Bearer Id            Start  Start ms              End  \
# 0      13114483460844900352   4/4/2019 12:01       770  4/25/2019 14:35
# 1      13114483482878900224   4/9/2019 13:04       235   4/25/2019 8:15
# 2      13114483484080500736   4/9/2019 17:42         1  4/25/2019 11:58
# 3      13114483485442799616   4/10/2019 0:31       486   4/25/2019 7:36
# 4      13114483499480700928  4/12/2019 20:10       565  4/25/2019 10:40
# ...                     ...              ...       ...              ...
# 149996  7277825670196679680   4/29/2019 7:28       451   4/30/2019 6:02
# 149997  7349883264234609664   4/29/2019 7:28       483  4/30/2019 10:41
# 149998 13114483573367300096   4/29/2019 7:28       283  4/30/2019 10:46
# 149999 13114483573367300096   4/29/2019 7:28       696  4/30/2019 10:40
# 150000                  NaN             None       NaN             None
#
#         End ms  Dur. (ms)            IMSI  MSISDN/Number           IMEI  \
# ...

# %%
mis_df=nan_values(df)
mis_df
# Out:
#                                           missing values  missing values %  \
# Nb of sec with 37500B < Vol UL                    130254                87
# Nb of sec with 6250B < Vol UL < 37500B            111843                75
# Nb of sec with 125000B < Vol DL                    97538                65
# TCP UL Retrans. Vol (Bytes)                        96649                64
# Nb of sec with 31250B < Vol DL < 125000B           93586                62
# Nb of sec with 1250B < Vol UL < 6250B              92894                62
# Nb of sec with 6250B < Vol DL < 31250B             88317                59
# TCP DL Retrans. Vol (Bytes)                        88146                59
# HTTP UL (Bytes)                                    81810                55
# HTTP DL (Bytes)                                    81474                54
# Avg RTT DL (ms)                                    27829                19
# ...

# %%
# df['Handset Type'].value_counts().sum()
df[df['IMSI'].isna()].isna().sum()
# Out:
# Bearer Id                                   561
# Start                                         1
# Start ms                                      1
# End                                           1
# End ms                                        1
# Dur. (ms)                                     1
# IMSI                                        570
# MSISDN/Number                               570
# IMEI                                        570
# Last Location Name                          561
# Avg RTT DL (ms)                             136
# Avg RTT UL (ms)                             137
# Avg Bearer TP DL (kbps)                       1
# Avg Bearer TP UL (kbps)                       1
# TCP DL Retrans. Vol (Bytes)                 208
# TCP UL Retrans. Vol (Bytes)                 217
# DL TP < 50 Kbps (%)                          30
# 50 Kbps < DL TP < 250 Kbps (%)               30
# 250 Kbps < DL TP < 1 Mbps (%)                30
# DL TP > 1 Mbps (%)                           30
# ...

# %%
top_ten_handset=to_percent(df,df['Handset Type'].value_counts()).head(10)
df[df['Handset Type'].isin(top_ten_handset.index)]['Handset Manufacturer'].value_counts()
# Out:
# Apple        43329
# Huawei       19752
# undefined     8987
# Samsung       4520
# Name: Handset Manufacturer, dtype: int64

# %%
top_ten_handset
# Out:
# Huawei B528S-23A               13
# Apple iPhone 6S (A1688)         6
# Apple iPhone 6 (A1586)          6
# undefined                       6
# Apple iPhone 7 (A1778)          4
# Apple iPhone Se (A1723)         3
# Apple iPhone 8 (A1905)          3
# Apple iPhone Xr (A2105)         3
# Samsung Galaxy S8 (Sm-G950F)    3
# Apple iPhone X (A1901)          3
# Name: Handset Type, dtype: float64

# %%
# df.set_option('display.float_format', '{:.0f}'.format)
more_xdr=df['MSISDN/Number'].value_counts()
more_xdr=more_xdr[more_xdr>1]
more_xdr
# Out:
# 33626320676    18
# 33614892860    17
# 33625779332    17
# 33659725664    16
# 33760536639    15
#                ..
# 33664424610     2
# 33659350323     2
# 33760125471     2
# 33670926298     2
# 33667456568     2
# Name: MSISDN/Number, Length: 29125, dtype: int64

# %%
df[df['IMSI']==208201715944176][['Start','End','Dur. (ms)','IMSI','MSISDN/Number','IMEI']]
# Out:
#                  Start             End  Dur. (ms)            IMSI  \
# 23055   4/16/2019 7:35  4/26/2019 9:29     870812 208201715944176
# 25026   4/14/2019 3:34  4/26/2019 9:29    1058072 208201715944176
# 25028  4/14/2019 15:30  4/26/2019 9:29    1015143 208201715944176
# 25030   4/15/2019 3:37  4/26/2019 9:29     971510 208201715944176
# 25032   4/15/2019 7:34  4/26/2019 9:29     957258 208201715944176
# 25044   4/17/2019 3:41  4/26/2019 9:29     798476 208201715944176
# 25058   4/18/2019 3:42  4/26/2019 9:29     711970 208201715944176
# 25085   4/19/2019 3:58  4/26/2019 9:29     624662 208201715944176
# 25103   4/19/2019 9:50  4/26/2019 9:29     603545 208201715944176
# 25141   4/20/2019 4:02  4/26/2019 9:29     538001 208201715944176
# 25237   4/21/2019 4:08  4/26/2019 9:29     451246 208201715944176
# 25430   4/22/2019 4:16  4/26/2019 9:29     364376 208201715944176
# 25963   4/23/2019 4:18  4/26/2019 9:29     277867 208201715944176
# ...
