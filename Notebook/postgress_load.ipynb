# %%
import sys
sys.path.append(r"C:\Users\Baslael\Documents\Kifiya\week2\script")

from main import load_data_from_postgres,nan_values,to_percent

# %%
query="SELECT * FROM xdr_data"

df=load_data_from_postgres(query)
df
# Out:
#            Bearer Id            Start  Start ms              End  End ms  \
# 0       1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1       1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2       1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3       1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4       1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
# ...              ...              ...       ...              ...     ...
# 149996  7.277826e+18   4/29/2019 7:28     451.0   4/30/2019 6:02   214.0
# 149997  7.349883e+18   4/29/2019 7:28     483.0  4/30/2019 10:41   187.0
# 149998  1.311448e+19   4/29/2019 7:28     283.0  4/30/2019 10:46   810.0
# 149999  1.311448e+19   4/29/2019 7:28     696.0  4/30/2019 10:40   327.0
# 150000           NaN             None       NaN             None     NaN
#
#         Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# ...

# %%
mis_df=nan_values(df)
mis_df
# Out:
#                                           missing values  missing values %  \
# Nb of sec with 37500B < Vol UL                    130254         86.835421
# Nb of sec with 6250B < Vol UL < 37500B            111843         74.561503
# Nb of sec with 125000B < Vol DL                    97538         65.024900
# TCP UL Retrans. Vol (Bytes)                        96649         64.432237
# Nb of sec with 31250B < Vol DL < 125000B           93586         62.390251
# Nb of sec with 1250B < Vol UL < 6250B              92894         61.928920
# Nb of sec with 6250B < Vol DL < 31250B             88317         58.877607
# TCP DL Retrans. Vol (Bytes)                        88146         58.763608
# HTTP UL (Bytes)                                    81810         54.539636
# HTTP DL (Bytes)                                    81474         54.315638
# Avg RTT DL (ms)                                    27829         18.552543
# ...

# %%
df['Handset Type'].value_counts().sum()
# Out:
# 149429

# %%
top_ten_handset=to_percent(df,df['Handset Type'].value_counts()).head(10)
top_ten_handset
# Out:
# Huawei B528S-23A                13.167912
# Apple iPhone 6S (A1688)          6.279291
# Apple iPhone 6 (A1586)           6.015293
# undefined                        5.991293
# Apple iPhone 7 (A1778)           4.217305
# Apple iPhone Se (A1723)          3.457977
# Apple iPhone 8 (A1905)           3.328644
# Apple iPhone Xr (A2105)          3.045313
# Samsung Galaxy S8 (Sm-G950F)     3.013313
# Apple iPhone X (A1901)           2.541983
# Name: Handset Type, dtype: float64
